# %%
from flair.models import SequenceTagger

tagger = SequenceTagger.load("f222.ckpt")
# Out:
# 2023-02-21 03:23:22,799 loading file f222.ckpt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a3851c5810d1> in <module>
#       1 from flair.models import SequenceTagger
#       2
# ----> 3 tagger = SequenceTagger.load("f222.ckpt")
#
# /usr/local/lib/python3.8/dist-packages/flair/nn/model.py in load(cls, model_path)
#     142             state = torch.load(f, map_location="cpu")
#     143
# --> 144         model = cls._init_model_with_state_dict(state)
#     145
#     146         if "model_card" in state:
#
# /usr/local/lib/python3.8/dist-packages/flair/models/sequence_tagger_model.py in _init_model_with_state_dict(cls, state, **kwargs)
#     617         weights = None if "weight_dict" not in state.keys() else state["weight_dict"]
#     618
# --> 619         if state["use_crf"]:
#     620             if "transitions" in state["state_dict"]:
# ...

# %% [markdown]
# # New section

# %% [markdown]
# # New section

# %%
# !wget -O f222.ckpt "https://huggingface.co/acheong08/f222/resolve/main/f222.ckpt"
# Out:
# --2023-02-22 03:19:58--  https://huggingface.co/acheong08/f222/resolve/main/f222.ckpt
# Resolving huggingface.co (huggingface.co)... 3.231.67.228, 54.235.118.239, 2600:1f18:147f:e800:671:b733:ecf3:a585, ...
# Connecting to huggingface.co (huggingface.co)|3.231.67.228|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import requests

# %%
get = requests.get('https://upload.wikimedia.org/wikipedia/commons/7/70/Chocolate_%28blue_background%29.jpg')
image_data = get.content
with open("image.jpg", "wb") as f:
        f.write(image_data)

# %%
import sys
print(sys.version)
# Out:
# 3.8.10 (default, Nov 14 2022, 12:59:47)
# [GCC 9.4.0]

# %%
# !ls -l
# Out:
# total 4165612
# -rw-r--r-- 1 root root 4265327916 Nov 10 00:49 f222.ckpt
# -rw-r--r-- 1 root root     246798 Feb 22 03:09 image.jpg
# drwxr-xr-x 1 root root       4096 Feb 17 19:30 sample_data

# %%
import os
print(os.getcwd())
# Out:
# /content
