# %%
# !pip install yt_dlp
from yt_dlp import YoutubeDL
with YoutubeDL({'overwrites':True, 'format':'bestaudio[ext=m4a]', 'outtmpl':'/content/audio.m4a'}) as ydl:
    ydl.download("https://youtu.be/SY2kZjVEd54")

# %%
# !unzip /content/vocal-remover-v5.0.3.zip -d /content/

# %%
# %cd vocal-remover
# !pip install -r requirements.txt

# %%
# !python inference.py --input /content/audio.m4a

# %%
from IPython.display import Audio

audio_path = '/content/vocal-remover/audio_Vocals.wav'
Audio(audio_path)

# %%
from google.colab import files

audio_path = '/content/vocal-remover/audio_Vocals.wav'
files.download(audio_path)
