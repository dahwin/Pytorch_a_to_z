# %%
# !pip install transformers

# %%
# !pip install diffusers
# !pip install accelerate

# %%
import transformers
from diffusers import StableDiffusionPipeline
import torch
model_id = "prompthero/openjourney-v4"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to("cuda")
pipe.safety_checker = lambda images, clip_input: (images, False)

prompt = "portrait of female draconian, intricate, elegant, highly detailed, digital painting, artstation, concept art, smooth, sharp focus, illustration, art by artgerm and greg rutkowski and alphonse mucha, 8k"
image = pipe(prompt).images[0]
image.save("dahwin.png")

# %%
# !pip show transformers

# %%
# !find / -iname "pytorch_model.bin" 2>/dev/null

# %%
d = 'dahwin'
d

# %%
from google.colab import files
import shutil

# Create a zip file of the folder
shutil.make_archive('models--prompthero--openjourney', 'zip', '/root/.cache/huggingface/hub/models--prompthero--openjourney')

# Download the zip file
files.download('models--prompthero--openjourney.zip')

# %%
# !mkdir -p /content/drive/MyDrive/

# %%
# !cp -r /root/.cache/huggingface/hub/models--prompthero--openjourney /content/drive/MyDrive/

# %%
# !du -sh /root/.cache/huggingface/hub/models--prompthero--openjourney

# %%
from google.colab import drive
# drive.mount('/content/drive')
# !cp -r /root/.cache/huggingface/hub/models--prompthero--openjourney '/content/drive/MyDrive/'

# %%
# !cp -r /root/.cache/huggingface/hub/models--prompthero--openjourney '/content/drive/MyDrive/'
