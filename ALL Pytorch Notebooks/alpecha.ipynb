# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("elinas/alpaca-30b-lora-int4")

model = AutoModelForCausalLM.from_pretrained("elinas/alpaca-30b-lora-int4")
