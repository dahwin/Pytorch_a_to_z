# %%
# !pip install transformers sentencepiece bitsandbytes accelerate

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("anon8231489123/vicuna-13b-GPTQ-4bit-128g")

model = AutoModelForCausalLM.from_pretrained("anon8231489123/vicuna-13b-GPTQ-4bit-128g")

input_text = "I love to eat"
input_ids = tokenizer.encode(input_text, return_tensors='pt')
output = model.generate(input_ids)
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
print(generated_text)

# %%
# %cd /content
# !apt-get -y install -qq aria2

# %%
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/vicuna-13b-GPTQ-4bit-128g/raw/main/config.json -d /content -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/vicuna-13b-GPTQ-4bit-128g/raw/main/generation_config.json -d /content -o generation_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/vicuna-13b-GPTQ-4bit-128g/raw/main/special_tokens_map.json -d /content -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/vicuna-13b-GPTQ-4bit-128g/resolve/main/tokenizer.model -d /content -o tokenizer.model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/vicuna-13b-GPTQ-4bit-128g/raw/main/tokenizer_config.json -d /content -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/vicuna-13b-GPTQ-4bit-128g/resolve/main/vicuna-13b-4bit-128g.safetensors -d /content -o vicuna-13b-4bit-128g.safetensors

# %%
import os
import glob

# Set the path to the content section
path = '/content/'

# Use the glob module to search for all files in the path
files = glob.glob(os.path.join(path, '*'))

# Print each file on a new line using the escape character \n
print('\n'.join(files))

# %%
# !git lfs install
# !git clone https://huggingface.co/gpt2
